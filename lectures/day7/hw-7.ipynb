# %% [markdown]
# ## Preface
#
# 본 과제를 위해 제공된 데이터를 외부인에게 절대 공개하지마세요.
#
#
# ### 우울률 비교 from 1_demo_update.xlsx
#
# 각종 plot으로 만들어보세요 ~
#
# - Plot use cases that we can use to visualize data
# - Scatter plot
# - Line plot
# - Bar plot
# - Histogram
# - Heatmap
# - Violin plot
# - Area plot
# - Pie chart
# - Bubble plot
# - Treemap
# ### reference
# -  https://www.data-to-viz.com/
# - Plot : https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
# - Linear regression : https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

# %%
import json
import numpy as np
# Checkif pandas is installed
try:
    import pandas 
except ImportError:
    # Run pip install pandas
    import pip
    pip.main(['install', 'pandas'])
    import pandas 
try:
    import matplotlib.pyplot as plt
except ImportError:
    # Run pip install matplotlib
    import pip
    pip.main(['install', 'matplotlib'])
    import matplotlib.pyplot as plt


# Read data from 1_demo_update.xlsx
df = pandas.read_excel('1_demo_update.xlsx')
print("==========================================")
print("not removed")
print(df)
# Out:
# ...
# not removed
#      subno  recall_total(%)  sex  age  edu(years)  MMSE  FAB  span task  기호쓰기  \
# 0      102        69.626022    2   22          15    29   18      4.600   115
# 1      103        86.139520    1   26          15    30   17      3.500    78
# 2      104        64.324194    2   19          13    28   18      4.700   108
# 3      108        67.820918    2   23          16    30   17      5.083   113
# 4      112        67.223725    2   20          13    30   18      4.800    93
# ..     ...              ...  ...  ...         ...   ...  ...        ...   ...
# 105    994        40.820000    1   71          12    28   17      2.666    42
# 106    996        34.810000    2   66          12    27   11      4.600    84
# 107    997        41.150000    2   70          14    29   17      2.666    80
# 108    998         6.380000    1   81           9    27   13      2.666    34
# 109    999        39.400000    1   67          16    28   17      4.400    48
#
# ...

# %%
# - Scatter plot
# - Line plot
# - Bar plot
# - Histogram
# - Heatmap
# - Violin plot
# - Area plot
# - Pie chart
# - Bubble plot
# - Treemap

# age vs depression score

# depression score can be calculated as follows:
# depressionScoreTotal = S-CESD * 2 + CESD


# 1. Scatter plot
x = df['age']
y = df['S-CESD'].fillna(0) * 2 + df['CESD'].fillna(0)


print(y)
print(f"average depression score: {np.mean(y)}")
print(f"max depression score: {np.max(y)}")

# # scatter argues: x, y, color, alpha, marker, s, linewidths, edgecolors, label, cmap, c
# # alpha: transparency
# # marker: o, v, ^, <, >, s, p, *, h, H, D, d, P, X
# # s: size
# # linewidths: line width
# # edgecolors: edge color
# # cmap: color map
# # c: color
# # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

plt.scatter(x, y, c=x, cmap='Set1',  alpha=0.5, marker='*', s=50, linewidths=1, 
            edgecolors='black', label='depression score')
plt.title('age vs depression score')
plt.xlabel('age')
plt.ylabel('depression score')
plt.show()
# Out:
# 0      33.0
# 1      48.0
# 2      27.0
# 3      58.0
# 4      25.0
#        ...
# 105    25.0
# 106    58.0
# 107    41.0
# 108    23.0
# 109     0.0
# Length: 110, dtype: float64
# average depression score: 29.272727272727273
# max depression score: 73.0

# %%
# 2. Line plot
# line plot is similar to scatter plot
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html


# Fit a polynomial regression model of degree 1
p = np.polyfit(x, y, 1)
print(f"polynomial regression model  of degree 2: {p}")
plt.plot(x, np.poly1d(p)(x), 'r--', label='polynomial regression model of degree 1')
plt.scatter(x, y, c=x, cmap='Set1',  alpha=0.5, marker='*', s=50, linewidths=1,
            edgecolors='black', label='depression score')
plt.title('age vs depression score')
plt.xlabel('age')
plt.ylabel('depression score')
plt.legend()
plt.show()
# Out:
# polynomial regression model  of degree 2: [-0.1190161  34.98225435]

# %%
# Fit a polynomial regression model of degree 2
p = np.polyfit(x, y, 2)
print(f"polynomial regression model of degree 2: {p}")
plt.plot(x, np.poly1d(p)(x), 'r--', label='polynomial regression model of degree 2')
plt.scatter(x, y, c=x, cmap='Set1',  alpha=0.5, marker='*', s=50, linewidths=1,
            edgecolors='black', label='depression score')
plt.title('age vs depression score')
plt.xlabel('age')
plt.ylabel('depression score')
plt.legend()
plt.show()
# Out:
# polynomial regression model of degree 2: [ 9.49165348e-03 -1.04259610e+00  5.07334388e+01]

# %%
# Fit a polynomial regression model of degree 3
p = np.polyfit(x, y, 3)
print(f"polynomial regression model of degree 3: {p}")
plt.plot(x, np.poly1d(p)(x), 'r--', label='polynomial regression model of degree 3')
plt.scatter(x, y, c=x, cmap='Set1',  alpha=0.5, marker='*', s=50, linewidths=1,
            edgecolors='black', label='depression score')
plt.title('age vs depression score')
plt.xlabel('age')
plt.ylabel('depression score')
plt.legend()
plt.show()
# Out:
# polynomial regression model of degree 3: [ 8.89172377e-04 -1.38340482e-01  6.30388804e+00 -4.64555443e+01]

# %%
# Regression with scipy
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

from scipy import stats

# Linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
print(f"slope: {slope}")
print(f"intercept: {intercept}")
print(f"r_value: {r_value}")
print(f"p_value: {p_value}")
print(f"std_err: {std_err}")
plt.plot(x, slope*x+intercept, 'r--', label='linear regression')
plt.scatter(x, y, c=x, cmap='Set1',  alpha=0.5, marker='*', s=50, linewidths=1,
            edgecolors='black', label='depression score')
plt.title('age vs depression score')
plt.xlabel('age')
plt.ylabel('depression score')
plt.legend()
plt.show()
# Out:
# slope: -0.11901610362251734
# intercept: 34.98225435287295
# r_value: -0.20045180697631235
# p_value: 0.03575515507072621
# std_err: 0.05597299718829107

# %%
# Non-linear regression
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html
from scipy.optimize import curve_fit

def func(x, a, b, c):
    return a * np.exp(-b * x) + c

popt, pcov = curve_fit(func, x, y)
print(f"popt: {popt}")
print(f"pcov: {pcov}")

plt.plot(x, func(x, *popt), 'r--', label='non-linear regression')
plt.scatter(x, y, c=x, cmap='Set1',  alpha=0.5, marker='*', s=50, linewidths=1,
            edgecolors='black', label='depression score')
plt.title('age vs depression score')
plt.xlabel('age')
plt.ylabel('depression score')
plt.legend()
plt.show()
# Out:
# popt: [1.00000000e+00 2.40111912e+07 2.92727273e+01]
# pcov: [[inf inf inf]
#  [inf inf inf]
#  [inf inf inf]]
# /home/jayleekr/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
# 3. Bar plot
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# Bar plot of depression score
plt.bar(x, y, color='blue', alpha=0.5, label='depression score')
plt.title('age vs depression score')
plt.xlabel('age')
plt.ylabel('depression score')
plt.legend()
plt.show()

# %%
# Bar plot of depression score with error bar
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.errorbar.html

# In a plot, an error bar is a line representing the range of values for a data point, typically the range of uncertainty for a mean value or a standard deviation. It can be useful to show the variability of data or the accuracy of measurements.

# Calculate the standard deviation of depression score
std = np.std(y)
print(f"standard deviation of depression score: {std}")

# Plot the bar plot
plt.bar(x, y, color='blue', alpha=0.5, label='depression score')

# Plot the error bar
plt.errorbar(x, y, yerr=std, fmt='o', color='black', ecolor='black', elinewidth=1, capsize=2, label='error bar')
# Out:
# standard deviation of depression score: 15.788320822055944
# <ErrorbarContainer object of 3 artists>

# %%
# 4. Histogram
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# Histogram of depression score

counts, bins = np.histogram(y, bins=10)
print(f"counts: {counts}")
print(f"bins: {bins}")

plt.stairs(counts, bins, fill=True, label='depression score')
plt.xlabel('depression score')
plt.ylabel('frequency')
plt.title('Histogram of depression score')
plt.legend()
plt.show()
# Out:
# counts: [12  5 17 25 15 14 14  6  1  1]
# bins: [ 0.   7.3 14.6 21.9 29.2 36.5 43.8 51.1 58.4 65.7 73. ]

# %%
#  5. Box plot of age vs depression score
plt.boxplot(y, labels=['depression score'], showmeans=True)
plt.title('Box plot of depression score')
plt.show()

# %%
# 6. Violin plot of age vs depression score
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.violinplot.html

# Easy example
plt.violinplot(y, showmeans=True)
plt.title('Violin plot of depression score')
plt.show()


# Very difficult example :D 
# data[(n, n_age)] : depression score of age of n*10 to (n+1)*10, with n*10 age
data=[]
for i in range(1, 10):
    df_of_nth_age=df[(df['age'] > i*10) & (df['age'] <= (i+1)*10)]
    # calculate depression score of nth age
    # depression_total =  S-CESD * 2 + CESD
    if df_of_nth_age.empty:
        continue
    dep_total_of_nth_age = df_of_nth_age['S-CESD'].fillna(0) * 2
    + df_of_nth_age['CESD'].fillna(0)
    data.append((dep_total_of_nth_age, i*10))

plt.violinplot([d[0] for d in data], [d[1] for d in data], showmeans=True, widths=5
               , showextrema=True, showmedians=True)
plt.title('Violin plot of age vs depression score')
plt.xlabel('age')
plt.ylabel('depression score')
plt.show()

# %%
# 7. Heatmap
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html
# Correlation matrix
df_delta= df
corr = df_delta.corr()

# Plot the heatmap
plt.imshow(corr, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr)), corr.columns)
plt.show()

# it seems like there are too many CESD of nth, let's remove them
for i in range(1, 21):
    df_delta = df_delta.drop(['CESD'+str(i)], axis=1)

plt.imshow(df_delta.corr(), cmap='hot', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(df_delta.corr())), df_delta.corr().columns, rotation='vertical')
plt.yticks(range(len(df_delta.corr())), df_delta.corr().columns)
plt.show()

# It's better now !!
# Out:
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50416 (\N{HANGUL SYLLABLE SSEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 55064 (\N{HANGUL SYLLABLE HWI}) missing from current font.
# ...

# %%
# 8. Bubble plot
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# Bubble plot of age vs depression score
plt.scatter(x, y, c=x, s=(y*30), cmap='Set1',  alpha=0.5, marker='o', linewidths=1,
            edgecolors='black', label='depression score')
plt.title('age vs depression score')
plt.xlabel('age')
plt.ylabel('depression score')
plt.legend()
plt.show()

# %%
# Plot use cases that we can use to visualize data
# reference: https://www.data-to-viz.com/
# Scatter plot
# Line plot
# Bar plot
# Histogram
# Heatmap
# Violin plot
# Area plot
# Pie chart
# Bubble plot
# Treemap

# Treemap
# We can use a treemap to compare the distribution of depression scores between young and old people
plt.figure(figsize=(10, 8))
try:
    import squarify
except ImportError:
    import pip
    pip.main(['install', 'squarify'])
    import squarify

squarify.plot(sizes=[young_depression.mean(), old_depression.mean()], label=['Young', 'Old'], alpha=.7 )
plt.axis('off')
plt.show()
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ### Plot 기억력 비교 from 1_demo_update.xlsx

# %%
# Ok, let's compare young and old people's recall scores from 1_demo_update.xlsx file

# Read data from 1_demo_update.xlsx
df2 = pandas.read_excel('1_demo_update.xlsx')


# print(df2)

# %%
# Plot use cases that we can use to visualize data
# reference: https://www.data-to-viz.com/
# Scatter plot
# Line plot
# Bar plot
# Histogram
# Heatmap
# Violin plot
# Area plot
# Pie chart
# Bubble plot
# Treemap


# age -> age
# recall_total -> recall_total(%)
x = df2['age']
y = df2['recall_total(%)']

# Line plot
m, b = np.polyfit(x, y, 1)
# Fit a quadratic regression line
p = np.polyfit(x, y, 2)
# y_fit = p[0]*x**2 + p[1]*x + p[2]

plt.plot(x, m*x + b)
# plt.plot(x, y_fit)
plt.show()

# %%
# scatter plot
plt.scatter(df2['age'], df2['recall_total(%)'], c=df2['age'], cmap='Set1', alpha=0.8,
            label='recall_total(%)')
plt.colorbar()

plt.xlabel('Age')
plt.ylabel('Recall total (%)')
plt.title('Recall total by age')
plt.show()

# %%
# Bar plot
plt.bar(df2['age'], df2['recall_total(%)'], color='green')
plt.xlabel('Age')
plt.ylabel('Recall total (%)')
plt.title('Recall total by age')
plt.show()

# %%
# Histogram
plt.hist(df2['recall_total(%)'], bins=20)
# bins is the number of bins
plt.xlabel('Recall total (%)')
plt.ylabel('Frequency')
plt.title('Recall total distribution')
plt.show()

# %%
# Heatmap
# Correlation matrix
# We can use a correlation matrix to see how different variables are correlated
# We can use a heatmap to visualize the correlation matrix
# We can use a correlation matrix to see how different variables are correlated
# We can use a heatmap to visualize the correlation matrix
corr = df2.corr()
# print(corr)

plt.figure(figsize=(10, 8))
plt.imshow(corr, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr)), corr.columns)
plt.show()
# Out:
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50416 (\N{HANGUL SYLLABLE SSEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jayleekr/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 55064 (\N{HANGUL SYLLABLE HWI}) missing from current font.
# ...

# %%
# Violin plot
# df2['age'] -> age
# df2['recall_total(%)'] -> recall_total(%)
plt.violinplot([df2['recall_total(%)'][df2['age'] < 50 ], df2['recall_total(%)'][df2['age'] >= 50]], showmeans=True)
plt.xticks([1, 2], ['Young', 'Old'])
plt.ylabel('Recall total (%)')
plt.title('Recall total by age group')
plt.show()

# %%
# Pie chart
# df2['age'] -> age
# df2['recall_total(%)'] -> recall_total(%)
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Young', 'Old'
sizes = [df2['recall_total(%)'][df2['age'] < 40 ].mean(), df2['recall_total(%)'][df2['age'] >= 40].mean()]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Bubble plot
# df2['age'] -> age
# df2['recall_total(%)'] -> recall_total(%)
plt.scatter(df2['age'], df2['recall_total(%)'], s=10, c=df2['age'], cmap='Set1', alpha=0.8,)
# bubble size is 10
# s is the size of the bubble
plt.xlabel('Age')
plt.ylabel('Recall total (%)')
plt.title('Recall total by age group')
plt.show()

# %%
# Treemap
# df2['age'] -> age
# df2['recall_total(%)'] -> recall_total(%)
plt.figure(figsize=(10, 8))
try:
    import squarify
except ImportError:
    import pip
    pip.main(['install', 'squarify'])
    import squarify

squarify.plot(sizes=[df2['recall_total(%)'][df2['age'] < 40 ].mean(), df2['recall_total(%)'][df2['age'] >= 40].mean()], label=['Young', 'Old'], alpha=.7 )
plt.axis('off')
plt.show()

# %% [markdown]
# # HW-#7!!!!!
#
# 우울률 비교 from 1_demo_update.xlsx
#
# 각종 plot으로 만들어보세요 ~
